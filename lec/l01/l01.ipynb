# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
#
#
# <center>
# <b><font size="+3">CS579: Online Social Network Analysis </font></b>
# <br>
# **Lecture 01**
# *[Dr. Aron Culotta](http://cs.iit.edu/~culotta)*
# *[Illinois Institute of Technology](http://iit.edu)*
#
# </center>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# What is an **online social network?**
#
# <br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 50px;">
# <img width=50% src="images/fb_logo.png"/>
# </span>
#
# - 1.2B users
# - 70B pieces of content shared / day
# - 150K messages sent / minute
#
# Sources: [\[1\]](http://www.statisticbrain.com/facebook-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/twitter_logo2.png"/>
# </span>
#
# <br>
#
# - 560M users
# - 400M tweets / day
# - 170B total tweets
#
# Sources: [\[1\]](http://www.statisticbrain.com/twitter-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/instagram.png"/>
# </span>
# <br>
#
# - 4B shared photos
# - 5M photos / day
# - 81 comments / second
#
# Sources: [\[1\]](http://www.huffingtonpost.com/brian-honigman/100-fascinating-social-me_b_2185281.html)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/sina-weibo.png"/>
# </span>
# <br>
#
# - 261M active users
# - 470M daily video views
# - 100M posts / day
#
# Sources: [\[1\]](http://expandedramblings.com/index.php/weibo-user-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### A large portion of the world's conversations are conducted in public.

# %% [markdown]
# ### Is there anything useful in this chatter?

# %% [markdown]
# ![brand](images/brand.png)
#
# [Radian6](http://www.salesforcemarketingcloud.com/blog/2012/08/social-media-insights-peekanalytics-at-work/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![flu](images/flu.png)
#
# - [Paul & Dredze \[2011\]](http://www.cs.jhu.edu/~mdredze/publications/twitter_health_icwsm_11.pdf)
# - [Culotta \[2010\]](http://cs.iit.edu/~culotta/pubs/culotta10towards.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![gallup](images/gallup.png)
#
# [O'Connor et al. \[2010\]](http://www.cs.cmu.edu/~nasmith/papers/oconnor+balasubramanyan+routledge+smith.icwsm10.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![djia](images/djia.png)
#
# [Bollen et al. \[2010\]](http://arxiv.org/pdf/1010.3003v1.pdf)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![crisis](images/crisis.png)
#
# [Rogstadius et al. \[2013\]](http://ufn.virtues.fi/~jakob/twitter/about.php)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![earthquake](images/earthquake.png)
#
# [Kumar et al. \[2011\]](http://www.public.asu.edu/~mabbasi2/papers/kumar2011tweettracker.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# **How does this** ![tweets](images/tweets.png) **become useful?**
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ###  Algorithms + Data = The Microscope of the 21st Century
#
# <table style="border: none;border-collapse: collapse;" border="0" >
# <tr><td><img src="images/tree.png" width=80%></td>
# <td>
# <ul>
# <li>Much as the microscope allowed scientists to see things they previously couldn't, now computer science provides new windows into human behavior
# <li>More human behavior is publicly observable than ever before
# <li>Supports sociology, anthropology, economics, psychology...
# <li>New algorithms are needed to sift through noise to find true patterns.
# <li>**Computational Social Science**
# </ul>
# </td></tr></table>
#
# <br><br><br><br>

# %% [markdown]
# ## This course combines...
# - Social network analysis
# - Natural language processing
# - Machine learning
#
# <br><br><br><br>
# <br><br><br><br>

# %% [markdown]
# ## Social Network Analysis
# - Study of the relationship between objects
# - Core tasks:
#   - Community detection
#   - Link prediction
#   - Spread of influence
#
#   <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Natural Language Processing
# - Algorithms allowing computers to make sense of human language
#   - text / audio
# - Core tasks:
#   - syntactic parsing
#   - entity/relation extraction
#   - sentiment classification
# - CS585
#
#   <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Machine Learning
# - Algorithms to detect patterns in data
# - Combines statistics and computer science
# - *CS584 Machine Learning*
#
# **Key tasks**
# - **Classification:** Assign a label to an object
# - **Regression:** Assign a real number to an object
# - **Clustering:** Group similar objects
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## This Course
# - Hands-on overview of social network, text analysis, machine learning
# - Survey of cutting edge research in this area
# - Technologies we'll use:
#   - Python / Jupyter notebooks
#   - Github
#   - Math
#   - Many APIs (Twitter, Facebook, LinkedIn, ...)
# - We'll use real data whenever possible
#   - Data are messy
#
# Course Website: <https://github.com/iit-cs579/main>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Why Jupyter Notebook?
#
# - Interactive; more fun.
# - See the code behind the math.
# <br><br><br><br><br>

# %% [markdown]
# $$ f(x) = \sum_i x_i $$
#
# <br><br><br>

# %%
def my_sum(x):
    total = 0
    for xi in x:
        total += xi
    return total

my_sum([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 36

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(5)*10, [50, 60, 70, 90, 100], 'bo-')
plt.xlabel('hours studying', size=14)
plt.ylabel('grade', size=14)
plt.show()

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### What are people saying about the eclipse right now?

# %%
import configparser
from TwitterAPI import TwitterAPI

consumer_key = 'S7iQEmSfH2ICIaDfKhmmr4o4q'
consumer_secret = '7Anj5i1kSawK1sT0yglcnaUBoSXiVSo3y60YoD8DZXuXMpbwoV'
access_token = '759979935075151872-krTlTnjkV63ejn9dK93anDuu0JR7VGa'
access_token_secret = 'DbnQTinTQVY57w8Kh892HcmMl4ZdbGnnOp4F2REmVVtxY'

def get_twitter():
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
#     config = configparser.ConfigParser()
#     config.read(config_file)
    twitter = TwitterAPI(consumer_key, consumer_secret, access_token, access_token_secret)
    return twitter

twitter = get_twitter()
print('Established Twitter connection.')
# Out:
# Established Twitter connection.

# %%
request = twitter.request('search/tweets', {'q': 'tamil', 'count': 1000}) 
tweets = [r for r in request]

# %%
[t['text'] for t in tweets]
# Out:
# ['RT @behindwoods: #Mersal Premeires on Oct 17th in US released by Atmus Entertainment &amp; US Tamil LLC....!!!! https://t.co/PTwSvJ9m1b',
#  'Tamil Quote\n#TAMILQUOTES #BESTTAMILQUOTES #tamil https://t.co/0p38D1HmHh',
#  'RT @Irshad5676: #Vishal has done more harm to Tamil Film industry than #Tamilrockers ...such a selfish guy always tried to save only his fi…',
#  '#WhatAmma hi anu hw r u whats ur nxt tamil mv',
#  "RT @vikatan: 'நோஞ்சான் ஆரவ்வை என் எதிரியாகப் பார்க்கவில்லை' - சினேகனின் பிக்பாஸ் அனுபவம் #VikatanExclusive  https://t.co/upycq59qwi https:/…",
#  "RT @Chiyaanism_Off: Director Vijay to direct #ArjunreddyRemake in Tamil with Chiyaan Vikram's son #DhruvVikram making his debut https://t.c…",
#  'Mersal - Maayon Tamil Lyric Official Released: https://t.co/6xKAavbwWZ via @YouTube',
#  'RT @behindwoods: #Mersal Premeires on Oct 17th in US released by Atmus Entertainment &amp; US Tamil LLC....!!!! https://t.co/PTwSvJ9m1b',
#  'Micro, cottage industries in Tamil Nadu write to PM, Jaitley to reduce GST from 18% to 5% https://t.co/6zOSURxw7E\n\nMicro and Cottage Indus…',
#  "RT @bbctamil: `சே' குவேராவின் வாரிசாக வாழ்வதில் உள்ள சவால்கள் என்ன? மனம் திறக்கும் மகன் https://t.co/b2WiAUBLIP",
#  'Which Heroine Tamil Cinema Favourite..?😇😍\n\nRT   - #KajalAggarwal \nFav - #NayantharaU \n\n@MsKajalAggarwal @NayantharaU https://t.co/WiY4u0xFHD',
#  "RT @Ramchander001: @news7tamil @drtamilisaibjp @nsitharaman What is going on? Is Tamil Nadu in India? These kind of things can't be tolerat…",
#  'RT @arpittripathi: Ramya Krishnan Mam has acted in numerous film over the years in multiple languages Hindi, Malayalam,Kannada,Tamil,Telugu…',
#  'RT @LMKMovieManiac: Looks like #2point0 will follow #Mersal as the 2nd Tamil / South Indian film to get its own Twitter emoji👌 Lyca is maki…',
#  'RT @navina2906: @doctorburn The tamil lyrics in this song are lit! Kudos to the one and only Sollisai thalaivan 💕👏 https://t.co/50Mm5MdmAv']

# %%
#harish: feature extraction what is countvectorizer: ADM

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(t['text'] for t in tweets)
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:30]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                   rt	66
#                tamil	63
#                https	62
#               mersal	22
#                  amp	16
#                 film	14
#                  oct	12
#        entertainment	9
#             released	9
#                   கள	9
#               vishal	9
#             oct 17th	8
#            tamil llc	8
#           tamil film	8
#      tamil llc https	8
#    oct 17th released	8
#            premeires	8
#     mersal premeires	8
#        film industry	8
#  atmus entertainment	8
# mersal premeires oct	8
#             industry	8
# entertainment amp tamil	8
#    entertainment amp	8
#        amp tamil llc	8
#        premeires oct	8
#                atmus	8
#  17th released atmus	8
#            llc https	8
#                   வத	8

# %%
#harish: ADM wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(t['text'] for t in tweets)
wordcloud = WordCloud(width=1200, height=800, background_color="white", 
                      stopwords=STOPWORDS | set(['eclipse', 'solar', 'rt', 'https', 'co'])).generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # First assignment, 999,999,999 points
#
# Complete the course survey!
# https://goo.gl/forms/Wk857dasCGQBoUjm1
#
# as soon as possible
#
#
# <br><br><br>

# %%
import pandas as pd
data = pd.read_csv('survey_results.csv')
headers = ['How familiar are you with version control? (git, svn, mercurial, cvs, etc.)',
          'How familiar are you with Python?',
          ]

for h in headers:
    plt.figure()
    data[h].plot(kind='hist')
    plt.ylabel('count')
    plt.xticks(np.arange(1, 6))
    plt.title(h)
plt.show()

# %%
from collections import Counter
mlq = 'Have you taken a course on Machine Learning or Data Mining?'
mlclass = Counter(data[mlq])
plt.figure()
plt.title(mlq)
plt.bar([0, 1], mlclass.values(), width=.5)
plt.xticks([0, 1], mlclass.keys())
plt.ylabel('count')
plt.show()

# %%
# Why take this course question.
# Note: this wont work since I removed this column from the data in github.
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(data['Why are you taking this course?'])
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:20]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Why are you taking this course?'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-59e4bed29164> in <module>()
#       4
#       5 vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
# ----> 6 text = vec.fit_transform(data['Why are you taking this course?'])
#       7 counts = text.sum(axis=0).getA1()
#       8 words = np.array(vec.get_feature_names())
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python3.5/dist-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Why are you taking this course?'

# %%
# Top words for people who have taken ML/DM
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(text, data[mlq])
print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f4abc7b67607> in <module>()
#       2 from sklearn.linear_model import LogisticRegression
#       3 clf = LogisticRegression()
# ----> 4 clf.fit(text, data[mlq])
#       5 print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
#
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'RT @behindwoods: #Mersal Premeires on Oct 17th in US released by Atmus Entertainment &amp; US Tamil LLC....!!!! https://t.co/PTwSvJ9m1b Tamil Quote\n#TAMILQUOTES #BESTTAMILQUOTES #tamil https://t.co/0p38D1HmHh RT @Irshad5676: #Vishal has done more harm to Tamil Film industry than #Tamilrockers ...such a selfish guy always tried to save only his fi… #WhatAmma hi anu hw r u whats ur nxt tamil mv RT @vikatan: \'நோஞ்சான் ஆரவ்வை என் எதிரியாகப் பார்க்கவில்லை\' - சினேகனின் பிக்பாஸ் அனுபவம் #VikatanExclusive  https://t.co/upycq59qwi https:/… RT @Chiyaanism_Off: Director Vijay to direct #ArjunreddyRemake in Tamil with Chiyaan Vikram\'s son #DhruvVikram making his debut https://t.c… RT @UshaSris: #noterrorism there @StateDept must end the occupation &amp; militarization by #srilanka of the Tamil homeland. It\'ll help to 1st… #noterrorism there @StateDept must end the occupation &amp; militarization by #srilanka of the Tamil homeland. It\'ll help to 1st send them back RT @FilmHistoryPic: REKHA turns 63 !\nBorn as Bhanurekha in Madras, to Tamil actors Gemini Ganesan &amp; Pushpavalli.\nSeen here in \'Utsav\', \'Sil… RT @kumbakonamtalks: As a Girl fan of Kollywood, Want release PK garu movies dubbed n Tamil👍 Fav #AttarintikiDaredi #khusi #TholiPrema 👌\n21… RT @56perumal: பிஜேபி.,யின் ஸ்லீப்பர் செல்... வேற யாரு நம்ம ராகுல் பையாதான்! குஜராத் பை எலக்சன்ல 7க்கு 5 சீட் அள்ளி